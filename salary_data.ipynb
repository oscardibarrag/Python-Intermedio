# %% [markdown]
# # Salary Data

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

datos = pd.read_csv('Salary_data.csv')
datos
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
#Revisar cuales columnas tienen campos vacios

datos.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
#Remplazar valores vacios

media = datos["Age"].median()
datos_age = datos["Age"].fillna(media)

vacio = 'Sin registro'
datos_gender = datos['Gender'].fillna(vacio)
datos_education = datos['Education Level'].fillna(vacio)
datos_job = datos['Job Title'].fillna(vacio)

media = datos['Years of Experience'].median()
datos_experience = datos['Years of Experience'].fillna(media)

media = datos['Salary'].median()
datos_salary = datos['Salary'].fillna(media)

datos_sv = pd.DataFrame({
    'Age':datos_age,
    'Gender':datos_gender,
    'Education Level':datos_education,
    'Job title':datos_job,
    'Years of Experience':datos_experience,
    'Salary':datos_salary})

# %%
#Datos corregidos
datos_sv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6704 non-null   float64
#  1   Gender               6704 non-null   object
#  2   Education Level      6704 non-null   object
#  3   Job title            6704 non-null   object
#  4   Years of Experience  6704 non-null   float64
#  5   Salary               6704 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
unique_count = datos_sv['Job title'].nunique()
unique_values = datos_sv['Job title'].unique()
print(f"Columna -Job Title- tiene {unique_count} valores unicos")
#print(unique_values)

maximo = datos_sv['Job title'].max()
print(f"El Titulo de trabajo con mejor salario es: {maximo}")
minimo = datos_sv['Job title'].min()
print(f"El Titulo de trabajo con menor salario es: {minimo}")
# Out:
# Columna -Job Title- tiene 194 valores unicos
# El Titulo de trabajo con mejor salario es: Web Developer
# El Titulo de trabajo con menor salario es: Account Manager

# %%
import matplotlib as plt
import matplotlib.pyplot as plt

font1 = {'family':'serif','color':'blue','size':15}
font2 = {'family':'serif','color':'red','size':20}


x = datos_sv['Age']
y = datos_sv['Salary']

#plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel("Edad",fontdict=font1)
plt.ylabel("Salario",fontdict=font1)
plt.title("Relación  Edad - Salario", fontdict=font2)


plt.show()

# %%
x = datos_sv['Age']

plt.hist(x)
plt.xlabel("Edad",fontdict=font1)
#plt.ylabel("Salario",fontdict=font1)
plt.title("Distribucion de la edad", fontdict=font2)
# Out:
# Text(0.5, 1.0, 'Distribucion de la edad')
