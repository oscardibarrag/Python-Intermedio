# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ### Pagina a realizar Web Scraping

# %%
promociones = requests.get('https://www.cyberpuerta.mx/Promociones/')
print(promociones)
print ('-----------')

soup = BeautifulSoup(promociones.text, 'html.parser')

print(soup.prettify())
# Out:
# <Response [200]>
# -----------
# <!DOCTYPE HTML>
# <html lang="es">
#  <head>
#   <link href="https://www.cyberpuerta.mx/out/generated/cms-pages.css?1593624763" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/em.selectbox.css?1691091666" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerlogin.css?1691091666" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headernotice.css?1691091666" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headercompare.css?1691091666" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerhelp.css?1691091666" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# ### Datos relevantes
#
# ##### > Producto
# ##### > Precio
# ##### > Descuento
# ##### > Disponibilidad

# %%
def obtener_contenido_pagina(url):
    response = requests.get(url)
    return response.content

def analizar_contenido_html(html):
    return BeautifulSoup(html, 'html.parser')

def procesar_pagina(soup):
    producto = []
    precio = []
    descuento = []
    existencia = []

    producto_items = soup.find_all('a', {'class': 'emproduct_right_title'})
    for productos in producto_items:
        producto_texto = productos['title']
        producto.append(producto_texto)
    
    
    precio_items = soup.find_all('label', {'class': 'price'})
    for precios in precio_items:
        precio_prod = precios.text.strip()
        precio.append(precio_prod)

    
    desc_items = soup.find_all('span', {'class': 'percent'})
    for descuentos in desc_items:
        desc_prod = descuentos.text.strip()
        descuento.append(desc_prod)
    
    existencia_items = soup.find_all('div',{'class': 'emstock'})
    for existencias in existencia_items:
        span_element = existencias.find('span')
        if span_element:
            cant = span_element.text.strip()
            existencia.append(cant)

    for i in range(len(producto)):
        data.append({
            "Producto": producto[i],
            "Precio": precio[i],
            "Descuento": descuento[i],
            "Existencia": existencia[i]
        })



def manejar_paginacion(url_base, num_paginas):
    for i in range(1, num_paginas + 1):
        url = url_base + str(i) + '/'
        contenido_pagina = obtener_contenido_pagina(url)
        soup = analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup)
        
data = []

url_base = 'https://www.cyberpuerta.mx/Promociones/'  
num_paginas = int(15)
manejar_paginacion(url_base, num_paginas)

# %%
#data
#by_precio = sorted(data,key=lambda precio : precio['Descuento'], reverse=True)
#by_precio

# %%
font1 = {'family':'serif','color':'blue','size':15}
font2 = {'family':'serif','color':'red','size':20}


y = data['Descuento']
x = data['Precio']

#plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel("Edad",fontdict=font1)
plt.ylabel("Salario",fontdict=font1)
plt.title("Relación  Edad - Salario", fontdict=font2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       1 font1 = {'family':'serif','color':'blue','size':15}
#       2 font2 = {'family':'serif','color':'red','size':20}
# ----> 5 y = data['Descuento']
#       6 x = data['Precio']
#       8 #plt.subplot(1,2,1)
#
# TypeError: list indices must be integers or slices, not str
